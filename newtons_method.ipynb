# %%
#We are given a function F and we define a function f(K) - given function - F
#We want to find the root of that function using Newton's method, which will
#then be solution for K in original function
def func(K):
    return (L/K)*(1-np.exp(-K*(t+a)))-F

# %%
#We will need the derivative of that function for Newton's method
def func_deriv(K):
    return (-L/K**2)*(1-np.exp(-K*(t+a)))+(L/K)*(t+a)*np.exp(-K*(t+a))

# %%
#Let's plot the function we want to be working with to see if it smooth enough
#that an application of Newton's method is appropriate
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
L = 1
t = 1
a = 1
F = 1

K = np.linspace(0, 10, 1000)

plt.plot(K,func(K))
# Out:
# /var/folders/sk/k6dfvs9x5h51jmj4d1tpr3tm0000gp/T/ipykernel_3372/3910071184.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   return (L/K)*(1-np.exp(-K*(t+a)))-F
# /var/folders/sk/k6dfvs9x5h51jmj4d1tpr3tm0000gp/T/ipykernel_3372/3910071184.py:5: RuntimeWarning: invalid value encountered in multiply
#   return (L/K)*(1-np.exp(-K*(t+a)))-F
# <img src="data:image/png;base64,..." width="640">

# %%
#Newton's method is an iterative scheme defined as x_{n+1} = x_n - f(x_)
def newtons(Tol, x_0 = 0):
    x_old = x_0
    x_new = x_old + Tol
    while np.abs(x_new-x_old) >= Tol:
        (x_old, x_new) = (x_new, x_new - func(x_new)/func_deriv(x_new))
    print('The estimate for K is {:f}.'.format(x_new))

# %%
newtons(0.1, 0)
# Out:
# The estimate for K is 0.796325.

# %%
newtons(0.000001, 0)
# Out:
# The estimate for K is 0.796812.

# %%
func(0.796325)
# Out:
# 0.00036301225649815194

# %%
func(0.796812)
# Out:
# 9.686479551795912e-08

# %%
#adding argparse so can run from command line
import argparse

parser = argparse.ArgumentParser(description='Apply Newton\'s method to estimate K in given function F.')
parser.add_argument('integers', metavar='N', type=int, nargs='+',
                    help='an integer for the accumulator')
parser.add_argument('--sum', dest='accumulate', action='store_const',
                    const=sum, default=max,
                    help='sum the integers (default: find the max)')

args = parser.parse_args()
print(args.accumulate(args.integers))
